# %%
ES_API='aUJhckQ1QUJLTE1YeFhaSW5CcGw6VkVPbzBFN3FTeDJZMjFiU0hwNENUUQ=='
CONN = 'https://3bf1318d9d5d468180ad45f7ed03ea23.us-central1.gcp.cloud.es.io:443'

from elasticsearch import Elasticsearch

elasco = Elasticsearch(
    CONN,
    api_key=ES_API,
)
elasco.info()
# Out:
# {'name': 'instance-0000000001',
#  'cluster_name': '3bf1318d9d5d468180ad45f7ed03ea23',
#  'cluster_uuid': '6ZfEeHy0Tx289HC-6IldFw',
#  'version': {'number': '8.14.1',
#   'build_flavor': 'default',
#   'build_type': 'docker',
#   'build_hash': '93a57a1a76f556d8aee6a90d1a95b06187501310',
#   'build_date': '2024-06-10T23:35:17.114581191Z',
#   'build_snapshot': False,
#   'lucene_version': '9.10.0',
#   'minimum_wire_compatibility_version': '7.17.0',
#   'minimum_index_compatibility_version': '7.0.0'},
#  'tagline': 'You Know, for Search'}

# %%
bonsai = Elasticsearch(
    'https://k0nxeh9mmq:uao3y6zftt@govtech-nucleus-unit-1660186680.us-east-1.bonsaisearch.net:443',
)
bonsai.info()
# Out:
# {'name': 'ip-172-31-54-195',
#  'cluster_name': 'elasticsearch',
#  'cluster_uuid': 'D_qHru2wRbSM6kZwsP853Q',
#  'version': {'number': '7.10.2',
#   'build_flavor': 'oss',
#   'build_type': 'tar',
#   'build_hash': '747e1cc71def077253878a59143c1f785afa92b9',
#   'build_date': '2021-01-13T00:42:12.435326Z',
#   'build_snapshot': False,
#   'lucene_version': '8.7.0',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %%
import requests
slug = 'govtech'
PLANE_PUBLIC_API_KEY="plane_api_35c9b24dca594bd69810ff63ddbbf446"
#url = f'https://api.plane.so/api/v1/workspaces/{slug}/projects/'
#r = requests.get(url=url, headers=f'x-api-key: {PLANE_PUBLIC_API_KEY}')
#print(r)


url = f"https://api.plane.so/api/v1/workspaces/{slug}/projects/"

headers = {"x-api-key": f"{PLANE_PUBLIC_API_KEY}"}

r = requests.get(url=url, headers=headers)
print(r.json())
# Out:
# {'next_cursor': '100:1:0', 'prev_cursor': '100:-1:1', 'next_page_results': False, 'prev_page_results': False, 'count': 5, 'total_pages': 1, 'total_results': 5, 'extra_stats': None, 'results': [{'id': 'a43e382b-6445-43d2-bf03-eeeb74feb0c8', 'total_members': 1, 'total_cycles': 0, 'total_modules': 0, 'is_member': True, 'sort_order': 25535.0, 'member_role': 20, 'is_deployed': False, 'created_at': '2024-06-13T04:01:40.475667Z', 'updated_at': '2024-06-13T04:01:44.511277Z', 'name': 'Tourism Ministry', 'description': '', 'description_text': None, 'description_html': None, 'network': 2, 'identifier': 'TOURI', 'emoji': None, 'icon_prop': None, 'module_view': True, 'cycle_view': True, 'issue_views_view': True, 'page_view': True, 'inbox_view': True, 'cover_image': 'https://images.unsplash.com/photo-1542202229-7d93c33f5d07?auto=format&fit=crop&q=80&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D&w=870&q=80', 'archive_in': 0, 'close_in': 0, 'logo_props': {'emoji': {'value': '128204'}, 'in_use': 'emoji'}, 'archived_at': None, 'created_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'updated_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'workspace': '488a9ad7-33f3-4382-b227-a71cb016c485', 'default_assignee': None, 'project_lead': None, 'estimate': None, 'default_state': None}, {'id': 'ac051d6a-39b6-4df2-b6a6-12d64b48c780', 'total_members': 1, 'total_cycles': 0, 'total_modules': 0, 'is_member': True, 'sort_order': 35535.0, 'member_role': 20, 'is_deployed': False, 'created_at': '2024-06-13T04:00:27.486997Z', 'updated_at': '2024-06-13T04:00:30.669039Z', 'name': 'Health Ministry', 'description': '', 'description_text': None, 'description_html': None, 'network': 2, 'identifier': 'HEALT', 'emoji': None, 'icon_prop': None, 'module_view': True, 'cycle_view': True, 'issue_views_view': True, 'page_view': True, 'inbox_view': True, 'cover_image': 'https://images.unsplash.com/photo-1542202229-7d93c33f5d07?auto=format&fit=crop&q=80&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D&w=870&q=80', 'archive_in': 0, 'close_in': 0, 'logo_props': {'emoji': {'value': '128204'}, 'in_use': 'emoji'}, 'archived_at': None, 'created_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'updated_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'workspace': '488a9ad7-33f3-4382-b227-a71cb016c485', 'default_assignee': None, 'project_lead': None, 'estimate': None, 'default_state': None}, {'id': 'd13c5167-f77d-43d6-8efc-35f2985316a3', 'total_members': 1, 'total_cycles': 0, 'total_modules': 0, 'is_member': True, 'sort_order': 45535.0, 'member_role': 20, 'is_deployed': False, 'created_at': '2024-06-12T23:57:49.258427Z', 'updated_at': '2024-06-12T23:57:52.714929Z', 'name': 'Transportation Ministry', 'description': '', 'description_text': None, 'description_html': None, 'network': 2, 'identifier': 'TRANS', 'emoji': None, 'icon_prop': None, 'module_view': True, 'cycle_view': True, 'issue_views_view': True, 'page_view': True, 'inbox_view': True, 'cover_image': 'https://images.unsplash.com/photo-1542202229-7d93c33f5d07?auto=format&fit=crop&q=80&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D&w=870&q=80', 'archive_in': 0, 'close_in': 0, 'logo_props': {'emoji': {'value': '128204'}, 'in_use': 'emoji'}, 'archived_at': None, 'created_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'updated_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'workspace': '488a9ad7-33f3-4382-b227-a71cb016c485', 'default_assignee': None, 'project_lead': None, 'estimate': None, 'default_state': None}, {'id': 'ef40d294-8737-4f3a-a97b-c1ed4ce2f174', 'total_members': 1, 'total_cycles': 0, 'total_modules': 0, 'is_member': True, 'sort_order': 55535.0, 'member_role': 20, 'is_deployed': False, 'created_at': '2024-06-12T23:56:54.913566Z', 'updated_at': '2024-06-12T23:57:00.869513Z', 'name': 'Education MInistry', 'description': '', 'description_text': None, 'description_html': None, 'network': 2, 'identifier': 'EDUCA', 'emoji': None, 'icon_prop': None, 'module_view': True, ...

# %%
res = r.json()['results']
for r in res:
    print(r)
    print('\n')
# Out:
# {'id': 'a43e382b-6445-43d2-bf03-eeeb74feb0c8', 'total_members': 1, 'total_cycles': 0, 'total_modules': 0, 'is_member': True, 'sort_order': 25535.0, 'member_role': 20, 'is_deployed': False, 'created_at': '2024-06-13T04:01:40.475667Z', 'updated_at': '2024-06-13T04:01:44.511277Z', 'name': 'Tourism Ministry', 'description': '', 'description_text': None, 'description_html': None, 'network': 2, 'identifier': 'TOURI', 'emoji': None, 'icon_prop': None, 'module_view': True, 'cycle_view': True, 'issue_views_view': True, 'page_view': True, 'inbox_view': True, 'cover_image': 'https://images.unsplash.com/photo-1542202229-7d93c33f5d07?auto=format&fit=crop&q=80&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D&w=870&q=80', 'archive_in': 0, 'close_in': 0, 'logo_props': {'emoji': {'value': '128204'}, 'in_use': 'emoji'}, 'archived_at': None, 'created_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'updated_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'workspace': '488a9ad7-33f3-4382-b227-a71cb016c485', 'default_assignee': None, 'project_lead': None, 'estimate': None, 'default_state': None}
#
#
# {'id': 'ac051d6a-39b6-4df2-b6a6-12d64b48c780', 'total_members': 1, 'total_cycles': 0, 'total_modules': 0, 'is_member': True, 'sort_order': 35535.0, 'member_role': 20, 'is_deployed': False, 'created_at': '2024-06-13T04:00:27.486997Z', 'updated_at': '2024-06-13T04:00:30.669039Z', 'name': 'Health Ministry', 'description': '', 'description_text': None, 'description_html': None, 'network': 2, 'identifier': 'HEALT', 'emoji': None, 'icon_prop': None, 'module_view': True, 'cycle_view': True, 'issue_views_view': True, 'page_view': True, 'inbox_view': True, 'cover_image': 'https://images.unsplash.com/photo-1542202229-7d93c33f5d07?auto=format&fit=crop&q=80&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D&w=870&q=80', 'archive_in': 0, 'close_in': 0, 'logo_props': {'emoji': {'value': '128204'}, 'in_use': 'emoji'}, 'archived_at': None, 'created_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'updated_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'workspace': '488a9ad7-33f3-4382-b227-a71cb016c485', 'default_assignee': None, 'project_lead': None, 'estimate': None, 'default_state': None}
#
#
# {'id': 'd13c5167-f77d-43d6-8efc-35f2985316a3', 'total_members': 1, 'total_cycles': 0, 'total_modules': 0, 'is_member': True, 'sort_order': 45535.0, 'member_role': 20, 'is_deployed': False, 'created_at': '2024-06-12T23:57:49.258427Z', 'updated_at': '2024-06-12T23:57:52.714929Z', 'name': 'Transportation Ministry', 'description': '', 'description_text': None, 'description_html': None, 'network': 2, 'identifier': 'TRANS', 'emoji': None, 'icon_prop': None, 'module_view': True, 'cycle_view': True, 'issue_views_view': True, 'page_view': True, 'inbox_view': True, 'cover_image': 'https://images.unsplash.com/photo-1542202229-7d93c33f5d07?auto=format&fit=crop&q=80&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D&w=870&q=80', 'archive_in': 0, 'close_in': 0, 'logo_props': {'emoji': {'value': '128204'}, 'in_use': 'emoji'}, 'archived_at': None, 'created_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'updated_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'workspace': '488a9ad7-33f3-4382-b227-a71cb016c485', 'default_assignee': None, 'project_lead': None, 'estimate': None, 'default_state': None}
#
#
# {'id': 'ef40d294-8737-4f3a-a97b-c1ed4ce2f174', 'total_members': 1, 'total_cycles': 0, 'total_modules': 0, 'is_member': True, 'sort_order': 55535.0, 'member_role': 20, 'is_deployed': False, 'created_at': '2024-06-12T23:56:54.913566Z', 'updated_at': '2024-06-12T23:57:00.869513Z', 'name': 'Education MInistry', 'description': '', 'description_text': None, 'description_html': None, 'network': 2, 'identifier': 'EDUCA', 'emoji': None, 'icon_prop': None, 'module_view': True, 'cycle_view': True, 'issue_views_view': True, 'page_view': True, 'inbox_view': True, 'cover_image': 'https://images.unsplash.com/photo-1542202229-7d93c33f5d07?auto=format&fit=crop&q=80&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D&w=870&q=80', 'archive_in': 0, 'close_in': 0, 'logo_props': {'emoji': {'value': '128204'}, 'in_use': 'emoji'}, 'archived_at': None, 'created_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'updated_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'workspace': '488a9ad7-33f3-4382-b227-a71cb016c485', 'default_assignee': None, 'project_lead': None, 'estimate': None, 'default_state': None}
#
#
# {'id': 'a30895aa-0f27-46b1-b782-9a4ff919cf2d', 'total_members': 2, 'total_cycles': 0, 'total_modules': 0, 'is_member': True, 'sort_order': 65535.0, 'member_role': 20, 'is_deployed': False, 'created_at': '2024-05-30T03:40:51.210266Z', 'updated_at': '2024-06-12T23:57:28.463625Z', 'name': 'Finance Ministry', 'description': '', 'description_text': None, 'description_html': None, 'network': 2, 'identifier': 'ASK12', 'emoji': None, 'icon_prop': None, 'module_view': True, 'cycle_view': True, 'issue_views_view': True, 'page_view': True, 'inbox_view': True, 'cover_image': 'https://images.unsplash.com/photo-1606768666853-403c90a981ad?auto=format&fit=crop&q=80&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D&w=870&q=80', 'archive_in': 0, 'close_in': 0, 'logo_props': {'emoji': {'value': '128204'}, 'in_use': 'emoji'}, 'archived_at': None, 'created_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'updated_by': 'f332d671-7c1b-44ca-a5ac-49171ed7d8fe', 'workspace': '488a9ad7-33f3-4382-b227-a71cb016c485', 'default_assignee': None, 'project_lead': None, 'estimate': None, 'default_state': None}
